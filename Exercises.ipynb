# %% [markdown]
# # Ex3 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import io

# %%
pip install requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 525.9 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#   WARNING: The script normalizer is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
data = pd.read_csv("u.user.txt", delimiter="|")
data.head(5)
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
data.set_index('user_id',inplace=True)

# %% [markdown]
# ### Step 4. See the first 25 entries

# %%
data.head(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# ...

# %% [markdown]
# ### Step 5. See the last 10 entries

# %%
data.tail(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %% [markdown]
# ### Step 6. What is the number of observations in the dataset?

# %%
len(data)
# Out:
# 943

# %% [markdown]
# ### Step 7. What is the number of columns in the dataset?

# %%
data.shape[1]
# Out:
# 4

# %% [markdown]
# ### Step 8. Print the name of all the columns.

# %%
for i in data.columns:
    print(i)
# Out:
# age
# gender
# occupation
# zip_code

# %% [markdown]
# ### Step 9. How is the dataset indexed?

# %% [markdown]
# ### Step 10. What is the data type of each column?

# %%
data.dtypes
# Out:
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# ### Step 11. Print only the occupation column

# %%
for i in data.occupation:
    print(i)
# Out:
# technician
# other
# writer
# technician
# other
# executive
# administrator
# administrator
# student
# lawyer
# other
# other
# educator
# scientist
# educator
# entertainment
# programmer
# other
# librarian
# homemaker
# writer
# writer
# artist
# artist
# engineer
# engineer
# librarian
# writer
# programmer
# student
# artist
# student
# student
# administrator
# homemaker
# student
# student
# other
# entertainment
# scientist
# engineer
# administrator
# librarian
# technician
# programmer
# marketing
# marketing
# administrator
# student
# writer
# educator
# student
# programmer
# executive
# programmer
# librarian
# none
# programmer
# educator
# healthcare
# engineer
# administrator
# marketing
# educator
# educator
# student
# student
# student
# engineer
# engineer
# scientist
# administrator
# student
# scientist
# entertainment
# student
# technician
# administrator
# administrator
# administrator
# student
# programmer
# other
# executive
# educator
# administrator
# ...

# %% [markdown]
# ### Step 12. How many different occupations are in this dataset?

# %%
visited = []
cnt=0
for i in range(0, len(data)):
    # print(data.iloc[i].occupation)
    
     if data.iloc[i].occupation not in visited:
        
         visited.append(data.iloc[i].occupation)
          
         cnt += 1
  
print(cnt)
# Out:
# 21

# %% [markdown]
# ### Step 13. What is the most frequent occupation?

# %% [markdown]
# ### Step 13. What is the most frequent occupation?

# %%
data.occupation.mode()[0]
# Out:
# 'student'

# %% [markdown]
# ### Step 14. Summarize the DataFrame.

# %%
data.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %% [markdown]
# ### Step 15. Summarize all the columns

# %% [markdown]
# ### Step 16. Summarize only the occupation column

# %%
data.occupation.describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %% [markdown]
# ### Step 17. What is the mean age of users?

# %%
data.age.mean()
# Out:
# 34.05196182396607

# %% [markdown]
# ### Step 18. What is the age with least occurrence?

# %%
a=data.age.value_counts()
a.index[-1]
# Out:
# 73
